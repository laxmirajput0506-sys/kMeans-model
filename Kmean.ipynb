# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
df=pd.read_csv("data.csv")

# %%
df
# Out:
#       ID     Name   Age  Salary Department Address(USA city)  \
# 0      1    Jonas  25.0   35000         HR       Phoenix, AZ
# 1      2     nick  30.0   42000         IT       Houston, TX
# 2      3  Charlie  28.0   39000    Finance       Chicago, IL
# 3      4    David  35.0   52000         IT     Charlotte, NC
# 4      5      Eva  26.0   36000         HR  Philadelphia, PA
# ...   ..      ...   ...     ...        ...               ...
# 4948  44   Rachel  30.0   41000         HR       Chicago, IL
# 4949  38    Linda  34.0   55000    Finance      Columbus, OH
# 4950  37    Kevin  31.0   43000      Sales       Seattle, WA
# 4951  97     Tito  39.0  250000      Sales   Los Angeles, CA
# 4952  21      Uma  26.0   36500    Finance   San Antonio, TX
#
#       Tax return Amount ($)
# 0                      6878
# 1                     10728
# 2                      9718
# 3                      8947
# 4                      2918
# ...                     ...
# 4948                   3805
# 4949                   2221
# 4950                  10132
# 4951                   5952
# 4952                  10842
#
# [4953 rows x 7 columns]

# %%
X = df[["Age", "Salary", "Tax return Amount ($)"]]

# %%
X
# Out:
#        Age  Salary  Tax return Amount ($)
# 0     25.0   35000                   6878
# 1     30.0   42000                  10728
# 2     28.0   39000                   9718
# 3     35.0   52000                   8947
# 4     26.0   36000                   2918
# ...    ...     ...                    ...
# 4948  30.0   41000                   3805
# 4949  34.0   55000                   2221
# 4950  31.0   43000                  10132
# 4951  39.0  250000                   5952
# 4952  26.0   36500                  10842
#
# [4953 rows x 3 columns]

# %%
df.isnull().sum()
# Out:
# ID                         0
# Name                       0
# Age                      480
# Salary                     0
# Department                 0
# Address(USA city)          0
# Tax return Amount ($)      0
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

# %%
df = df.dropna(subset=["Age", "Salary", "Tax return Amount ($)"])

# %%
X = df[["Age", "Salary", "Tax return Amount ($)"]]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

# %%
kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)

df["Cluster"] = kmeans.fit_predict(X_scaled)

# %%
kmeans
# Out:
# KMeans(n_clusters=3, n_init=10, random_state=42)

# %%
import matplotlib.pyplot as plt

plt.scatter(
    df["Age"],
    df["Salary"],
    c=df["Cluster"],
    s=100
)

plt.title("data Segmentation using K-Means")

plt.xlabel("age")

plt.ylabel("salary")

plt.grid(True)

plt.show()
